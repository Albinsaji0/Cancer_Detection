# %% [markdown]
# <a href="https://colab.research.google.com/github/Albinsaji0/Cancer_Detection/blob/main/algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("data.csv")
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
df.drop(df.columns[[0, 1]], axis=1, inplace=True)

# %%
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
numeric_df = df.select_dtypes(include='number')

# %%
plt.figure(figsize=(18,14))
sns.heatmap(numeric_df.corr(), annot=True, cmap='cubehelix_r')
plt.show()
